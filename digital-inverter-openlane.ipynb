# %% [markdown]
# <a href="https://colab.research.google.com/github/claytonfariasEC/OpenGL-GSDE-LOGO/blob/master/digital-inverter-openlane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Digital inverter with OpenLane
#
# ```
# Copyright 2022 Google LLC.
# SPDX-License-Identifier: Apache-2.0
# ```
#
# Run a simple digital inverter design thru the [OpenLane](https://github.com/The-OpenROAD-Project/OpenLane/) GDS to RTL flow targeting the [open source SKY130 PDK](https://github.com/google/skywater-pdk/).

# %%
#@title Install dependencies {display-mode: "form"}
#@markdown - Click the ▷ button to setup the digital design environment based on [conda-eda](https://github.com/hdl/conda-eda).

openlane_version = 'latest' #@param {type:"string"}
open_pdks_version = 'latest' #@param {type:"string"}

if openlane_version == 'latest':
  openlane_version = ''
if open_pdks_version == 'latest':
  open_pdks_version = ''

import os
import pathlib

# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xj bin/micromamba
conda_prefix_path = pathlib.Path('conda-env')
CONDA_PREFIX = str(conda_prefix_path.resolve())
# !bin/micromamba create --yes --prefix $CONDA_PREFIX
# !echo 'python ==3.7*' >> {CONDA_PREFIX}/conda-meta/pinned
# !CI=0 bin/micromamba install --yes --prefix $CONDA_PREFIX \
                     --channel litex-hub \
                     --channel main \
                     openlane={openlane_version} \
                     open_pdks.sky130a={open_pdks_version}
# !python -m pip install gdstk gdstk
PATH = os.environ['PATH']
# %env CONDA_PREFIX={CONDA_PREFIX}
# %env PATH={CONDA_PREFIX}/bin:{PATH}
# Out:
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
# Empty environment created at prefix: /content/conda-env
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
#
# Pinned packages:
#   - python 3.7*
#
#
# Transaction
#
#   Prefix: /content/conda-env
#
#   Updating specs:
#
#    - openlane=*
#    - open_pdks.sky130a=*
#
#
#   Package                              Version  Build                 Channel        Size
# ───────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                          0.1  main                  main            3kB
#   + _openmp_mutex                          5.1  1_gnu                 main           21kB
#   + bzip2                                1.0.8  h7b6447c_0            main          107kB
#   + ca-certificates                 2023.01.10  h06a4308_0            main          130kB
#   + cairo                              1.14.12  h8948797_3            main            1MB
#   + certifi                          2022.12.7  py37h06a4308_0        main          155kB
#   + click                                8.0.4  py37h06a4308_0        main          152kB
#   + dbus                               1.13.18  hb2f20db_0            main          600kB
#   + expat                                2.4.9  h6a678d5_0            main          192kB
#   + flit-core                            3.6.0  pyhd3eb1b0_0          main           43kB
#   + fmt                                  8.1.1  hd09550d_1            main          182kB
#   + fontconfig                          2.13.0  h9420a91_0            main          298kB
#   + freetype                            2.12.1  h4a9f257_0            main          972kB
#   + gdbm                                  1.18  hd4cb3f1_4            main          197kB
#   + glib                                2.69.1  he621ea3_2            main            2MB
#   + gmp                                  6.2.1  h295c915_3            main          822kB
#   + gst-plugins-base                    1.14.1  h6a678d5_1            main            2MB
#   + gstreamer                           1.14.1  h5eee18b_1            main            2MB
#   + icu                                   58.2  he6710b0_3            main           24MB
#   + importlib-metadata                  4.11.3  py37h06a4308_0        main           41kB
#   + jpeg                                    9e  h5eee18b_1            main          281kB
#   + klayout                0.28.8_3_g21a263439  20230524_010725_py37  litex-hub      26MB
#   + ld_impl_linux-64                      2.38  h1181459_1            main          749kB
#   + libboost                            1.73.0  h28710b8_12           main           22MB
#   + libffi                               3.4.2  h6a678d5_6            main          138kB
#   + libgcc-ng                           11.2.0  h1234567_1            main            9MB
#   + libgomp                             11.2.0  h1234567_1            main          573kB
#   + libpng                              1.6.39  h5eee18b_0            main          363kB
#   + libstdcxx-ng                        11.2.0  h1234567_1            main            6MB
#   + libuuid                             1.41.5  h5eee18b_0            main           29kB
#   + libxcb                                1.15  h7f8727e_0            main          623kB
#   + libxml2                              2.9.9  20220706_155948       litex-hub       1MB
#   + lz4-c                                1.9.4  h6a678d5_0            main          164kB
#   + magic                   8.3.389_0_g1d8fcca  20230412_103222       litex-hub       5MB
#   + ncurses                                6.4  h6a678d5_0            main            1MB
#   + netgen                  1.5.251_0_gd111fa0  20230412_103222       litex-hub     804kB
#   + open_pdks.sky130a       1.0.406_0_g0c37b7c  20230412_103222       litex-hub     130MB
#   + openlane            2023.04.12_0_g23e367a9  20230412_103222       litex-hub      12MB
#   + openroad               2.0_7681_g850238c2f  20230412_103222       litex-hub      24MB
#   + openssl                             1.1.1t  h7f8727e_0            main            4MB
#   + pcre                                  8.45  h295c915_0            main          263kB
#   + pip                                 22.3.1  py37h06a4308_0        main            3MB
#   + pixman                              0.40.0  h7f8727e_1            main          645kB
#   + python                              3.7.16  h7a1cb2a_0            main           49MB
#   + pyyaml                                 6.0  py37h5eee18b_1        main          184kB
#   + qt                                   5.9.7  h5867ecd_1            main           90MB
#   + readline                               8.2  h5eee18b_0            main          468kB
#   + ruby                                 3.1.2  h006b21b_1            main            9MB
#   + setuptools                          65.6.3  py37h06a4308_0        main            1MB
#   + spdlog                               1.9.2  hd09550d_0            main          217kB
#   + sqlite                              3.41.2  h5eee18b_0            main            2MB
#   + tcllib                  1_21_47_g6c321309d  20230524_010725       litex-hub       2MB
#   + tk                                  8.6.12  h1ccaba5_0            main            3MB
#   + typing_extensions                    4.4.0  py37h06a4308_0        main           46kB
#   + wheel                               0.38.4  py37h06a4308_0        main           59kB
#   + xz                                  5.2.10  h5eee18b_1            main          459kB
#   + yaml                                 0.2.5  h7b6447c_0            main           89kB
#   + yosys                   0.29_40_gcac1bc6fb  20230524_010725_py37  litex-hub      11MB
#   + zipp                                3.11.0  py37h06a4308_0        main           18kB
#   + zlib                                1.2.13  h5eee18b_0            main          128kB
#   + zstd                                 1.5.5  hc292b87_0            main            1MB
#
#   Summary:
#
#   Install: 61 packages
#
#   Total download: 454MB
#
# ───────────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Linking open_pdks.sky130a-1.0.406_0_g0c37b7c-20230412_103222
# Linking _libgcc_mutex-0.1-main
# Linking libstdcxx-ng-11.2.0-h1234567_1
# Linking ld_impl_linux-64-2.38-h1181459_1
# Linking ca-certificates-2023.01.10-h06a4308_0
# Linking libgomp-11.2.0-h1234567_1
# Linking _openmp_mutex-5.1-1_gnu
# Linking libgcc-ng-11.2.0-h1234567_1
# Linking libuuid-1.41.5-h5eee18b_0
# Linking lz4-c-1.9.4-h6a678d5_0
# Linking gmp-6.2.1-h295c915_3
# Linking pixman-0.40.0-h7f8727e_1
# Linking bzip2-1.0.8-h7b6447c_0
# Linking yaml-0.2.5-h7b6447c_0
# Linking libxcb-1.15-h7f8727e_0
# Linking jpeg-9e-h5eee18b_1
# Linking icu-58.2-he6710b0_3
# Linking expat-2.4.9-h6a678d5_0
# Linking xz-5.2.10-h5eee18b_1
# Linking openssl-1.1.1t-h7f8727e_0
# Linking ncurses-6.4-h6a678d5_0
# Linking pcre-8.45-h295c915_0
# Linking libffi-3.4.2-h6a678d5_6
# Linking fmt-8.1.1-hd09550d_1
# Linking zlib-1.2.13-h5eee18b_0
# Linking readline-8.2-h5eee18b_0
# Linking spdlog-1.9.2-hd09550d_0
# Linking zstd-1.5.5-hc292b87_0
# Linking libpng-1.6.39-h5eee18b_0
# Linking glib-2.69.1-he621ea3_2
# Linking tk-8.6.12-h1ccaba5_0
# Linking gdbm-1.18-hd4cb3f1_4
# Linking sqlite-3.41.2-h5eee18b_0
# Linking libboost-1.73.0-h28710b8_12
# Linking freetype-2.12.1-h4a9f257_0
# Linking gstreamer-1.14.1-h5eee18b_1
# Linking dbus-1.13.18-hb2f20db_0
# Linking ruby-3.1.2-h006b21b_1
# Linking python-3.7.16-h7a1cb2a_0
# Linking wheel-0.38.4-py37h06a4308_0
# Linking gst-plugins-base-1.14.1-h6a678d5_1
# Linking certifi-2022.12.7-py37h06a4308_0
# Linking setuptools-65.6.3-py37h06a4308_0
# Linking pip-22.3.1-py37h06a4308_0
# Linking pyyaml-6.0-py37h5eee18b_1
# Linking zipp-3.11.0-py37h06a4308_0
# Linking libxml2-2.9.9-20220706_155948
# Linking netgen-1.5.251_0_gd111fa0-20230412_103222
# Linking yosys-0.29_40_gcac1bc6fb-20230524_010725_py37
# Linking tcllib-1_21_47_g6c321309d-20230524_010725
# Linking flit-core-3.6.0-pyhd3eb1b0_0
# Linking fontconfig-2.13.0-h9420a91_0
# Linking typing_extensions-4.4.0-py37h06a4308_0
# Linking cairo-1.14.12-h8948797_3
# Linking qt-5.9.7-h5867ecd_1
# Linking importlib-metadata-4.11.3-py37h06a4308_0
# Linking click-8.0.4-py37h06a4308_0
# Linking magic-8.3.389_0_g1d8fcca-20230412_103222
# Linking klayout-0.28.8_3_g21a263439-20230524_010725_py37
# Linking openroad-2.0_7681_g850238c2f-20230412_103222
# Linking openlane-2023.04.12_0_g23e367a9-20230412_103222
#
# Transaction finished
#
# To activate this environment, use:
#
#     micromamba activate /content/conda-env
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -p /content/conda-env mycommand
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gdstk
#   Downloading gdstk-0.9.41-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gdstk) (1.22.4)
# Installing collected packages: gdstk
# Successfully installed gdstk-0.9.41
# env: CONDA_PREFIX=/content/conda-env
# env: PATH=/content/conda-env/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin

# %% [markdown]
# ## Write verilog

# %%
# %%writefile inverter.v
# module inverter(input wire a,input wire b, output wire out);
#     assign out = !(a && b) ;
# endmodule
# Out:
# Overwriting inverter.v

# %% [markdown]
# ## Write configuration
#
# [Documentation](https://openlane.readthedocs.io/en/latest/reference/configuration.html)

# %%
# %%writefile config.json
#
# {
#     "DESIGN_NAME": "inverter",
#     "VERILOG_FILES": "dir::inverter.v",
#     "CLOCK_TREE_SYNTH": false,
#     "CLOCK_PORT": null,
#     "PL_RANDOM_GLB_PLACEMENT": true,
#     "FP_SIZING": "absolute",
#     "DIE_AREA": "0 0 34.5 57.12",
#     "PL_TARGET_DENSITY": 0.75,
#     "FP_PDN_AUTO_ADJUST": false,
#     "FP_PDN_VPITCH": 25,
#     "FP_PDN_HPITCH": 25,
#     "FP_PDN_VOFFSET": 5,
#     "FP_PDN_HOFFSET": 5
#
# }
# Out:
# Overwriting config.json

# %% [markdown]
# ## Run OpenLane Flow
#
# [OpenLane](https://openlane.readthedocs.io/en/latest/) is an automated [RTL](https://en.wikipedia.org/wiki/Register-transfer_level) to [GDSII](https://en.wikipedia.org/wiki/GDSII) flow based on several components including [OpenROAD](https://theopenroadproject.org/), [Yosys](https://yosyshq.net/yosys/), [Magic](http://www.opencircuitdesign.com/magic/), [Netgen](http://opencircuitdesign.com/netgen/) and custom methodology scripts for design exploration and optimization targeting [open source PDKs](https://github.com/google/open-source-pdks).
#
# ![img](https://openlane.readthedocs.io/en/latest/_images/flow_v1.png)

# %%
# %env PDK=sky130A
# !flow.tcl -design .
# Out:
# env: PDK=sky130A
# OpenLane 2023.04.12_0_g23e367a9-conda
# All rights reserved. (c) 2020-2022 Efabless Corporation and contributors.
# Available under the Apache License, version 2.0. See the LICENSE file for more details.
#
# [INFO]: Using configuration in 'config.json'...
# [INFO]: PDK Root: /content/conda-env/share/pdk
# [INFO]: Process Design Kit: sky130A
# [INFO]: Standard Cell Library: sky130_fd_sc_hd
# [INFO]: Optimization Standard Cell Library: sky130_fd_sc_hd
# [INFO]: Run Directory: /content/runs/RUN_2023.05.26_14.45.29
# [INFO]: Preparing LEF files for the nom corner...
# [INFO]: Preparing LEF files for the min corner...
# [INFO]: Preparing LEF files for the max corner...
# [STEP 1]
# [INFO]: Running Synthesis (log: runs/RUN_2023.05.26_14.45.29/logs/synthesis/1-synthesis.log)...
# [STEP 2]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.05.26_14.45.29/logs/synthesis/2-sta.log)...
# [STEP 3]
# [INFO]: Running Initial Floorplanning (log: runs/RUN_2023.05.26_14.45.29/logs/floorplan/3-initial_fp.log)...
# [INFO]: Floorplanned with width 13.34 and height 24.48.
# [STEP 4]
# [INFO]: Running IO Placement...
# [STEP 5]
# [INFO]: Running Tap/Decap Insertion (log: runs/RUN_2023.05.26_14.45.29/logs/floorplan/5-tap.log)...
# [INFO]: Power planning with power {VPWR} and ground {VGND}...
# [STEP 6]
# [INFO]: Generating PDN (log: runs/RUN_2023.05.26_14.45.29/logs/floorplan/6-pdn.log)...
# [STEP 7]
# [INFO]: Performing Random Global Placement (log: runs/RUN_2023.05.26_14.45.29/logs/placement/7-global.log)...
# [STEP 8]
# [INFO]: Running Placement Resizer Design Optimizations (log: runs/RUN_2023.05.26_14.45.29/logs/placement/8-resizer.log)...
# [STEP 9]
# [INFO]: Running Detailed Placement (log: runs/RUN_2023.05.26_14.45.29/logs/placement/9-detailed.log)...
# [STEP 10]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.05.26_14.45.29/logs/placement/10-sta.log)...
# [STEP 11]
# [INFO]: Running Placement Resizer Timing Optimizations (log: runs/RUN_2023.05.26_14.45.29/logs/cts/11-resizer.log)...
# [STEP 12]
# [INFO]: Running Global Routing Resizer Design Optimizations (log: runs/RUN_2023.05.26_14.45.29/logs/routing/12-resizer_design.log)...
# [STEP 13]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.05.26_14.45.29/logs/routing/13-sta-resizer_design.log)...
# [STEP 14]
# [INFO]: Running Global Routing Resizer Timing Optimizations (log: runs/RUN_2023.05.26_14.45.29/logs/routing/14-resizer_timing.log)...
# [STEP 15]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.05.26_14.45.29/logs/routing/15-sta-resizer_timing.log)...
# [STEP 16]
# [INFO]: Running Global Routing (log: runs/RUN_2023.05.26_14.45.29/logs/routing/16-global.log)...
# [INFO]: Starting OpenROAD Antenna Repair Iterations...
# [STEP 17]
# [INFO]: Writing Verilog (log: runs/RUN_2023.05.26_14.45.29/logs/routing/16-global_write_netlist.log)...
# [STEP 18]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.05.26_14.45.29/logs/routing/18-sta-groute.log)...
# [STEP 19]
# [INFO]: Running Fill Insertion (log: runs/RUN_2023.05.26_14.45.29/logs/routing/19-fill.log)...
# [STEP 20]
# [INFO]: Running Detailed Routing (log: runs/RUN_2023.05.26_14.45.29/logs/routing/20-detailed.log)...
# [INFO]: No DRC violations after detailed routing.
# [STEP 21]
# [INFO]: Checking Wire Lengths (log: runs/RUN_2023.05.26_14.45.29/logs/routing/21-wire_lengths.log)...
# [STEP 22]
# [INFO]: Running SPEF Extraction at the min process corner (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/22-parasitics_extraction.min.log)...
# [STEP 23]
# [INFO]: Running Multi-Corner Static Timing Analysis at the min process corner (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/23-rcx_mcsta.min.log)...
# [STEP 24]
# [INFO]: Running SPEF Extraction at the max process corner (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/24-parasitics_extraction.max.log)...
# [STEP 25]
# [INFO]: Running Multi-Corner Static Timing Analysis at the max process corner (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/25-rcx_mcsta.max.log)...
# [STEP 26]
# [INFO]: Running SPEF Extraction at the nom process corner (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/26-parasitics_extraction.nom.log)...
# [STEP 27]
# [INFO]: Running Multi-Corner Static Timing Analysis at the nom process corner (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/27-rcx_mcsta.nom.log)...
# [STEP 28]
# [INFO]: Running Single-Corner Static Timing Analysis at the nom process corner (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/28-rcx_sta.log)...
# [WARNING]: Module sky130_ef_sc_hd__decap_12 blackboxed during sta
# [WARNING]: Module sky130_fd_sc_hd__fill_1 blackboxed during sta
# [STEP 29]
# [INFO]: Creating IR Drop Report (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/29-irdrop.log)...
# [STEP 30]
# [INFO]: Running Magic to generate various views...
# [INFO]: Streaming out GDSII with Magic (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/30-gdsii.log)...
# [INFO]: Generating MAGLEF views...
# [INFO]: Generating lef with Magic (/content/runs/RUN_2023.05.26_14.45.29/logs/signoff/30-lef.log)...
# [STEP 31]
# [INFO]: Streaming out GDSII with KLayout (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/31-gdsii-klayout.log)...
# [STEP 32]
# [INFO]: Running XOR on the layouts using KLayout (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/32-xor.log)...
# [INFO]: No XOR differences between KLayout and Magic gds.
# [STEP 33]
# [INFO]: Running Magic Spice Export from LEF (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/33-spice.log)...
# [STEP 34]
# [INFO]: Writing Powered Verilog (logs: runs/RUN_2023.05.26_14.45.29/logs/signoff/34-write_powered_def.log, runs/RUN_2023.05.26_14.45.29/logs/signoff/34-write_powered_verilog.log)...
# [STEP 35]
# [INFO]: Writing Verilog (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/34-write_powered_verilog.log)...
# [STEP 36]
# [INFO]: Running LVS (log: runs/RUN_2023.05.26_14.45.29/logs/signoff/36-lvs.lef.log)...
# [ERROR]: There are LVS errors in the design: See 'runs/RUN_2023.05.26_14.45.29/reports/signoff/36-inverter.lvs.rpt' for a summary and 'runs/RUN_2023.05.26_14.45.29/logs/signoff/36-lvs.lef.log' for details.
# [ERROR]: Step(36:lvs) failed with error:
# -code 1 -level 0 -errorstack {INNER {invokeStk1 throw_error} CALL {quit_on_lvs_error -rpt /content/runs/RUN_2023.05.26_14.45.29/reports/signoff/36-inverter.lvs.rpt -log /content/runs/RUN_2023.05.26_14.45.29/logs/signoff/36-lvs.lef.log} CALL run_lvs CALL run_lvs_step CALL {run_non_interactive_mode -design .}} -errorcode NONE -errorinfo {
#     while executing
# "throw_error"
#     (procedure "quit_on_lvs_error" line 13)
#     invoked from within
# "quit_on_lvs_error -rpt $count_lvs_rpt -log $log"
#     (procedure "run_lvs" line 76)
#     invoked from within
# "run_lvs"
#     (procedure "run_lvs_step" line 10)
#     invoked from within
# "run_lvs_step"} -errorline 1
# [INFO]: Saving current set of views in 'runs/RUN_2023.05.26_14.45.29/results/final'...
# [INFO]: Generating final set of reports...
# [INFO]: Created manufacturability report at 'runs/RUN_2023.05.26_14.45.29/reports/manufacturability.rpt'.
# [INFO]: Created metrics report at 'runs/RUN_2023.05.26_14.45.29/reports/metrics.csv'.
# [INFO]: Saving runtime environment...
# [ERROR]: Flow failed.
# [INFO]: The failure may have been because of the following warnings:
# [WARNING]: Module sky130_ef_sc_hd__decap_12 blackboxed during sta
# [WARNING]: Module sky130_fd_sc_hd__fill_1 blackboxed during sta

# %% [markdown]
# ## Display layout

# %%
import pathlib
import gdstk
import IPython.display

gdss = sorted(pathlib.Path('runs').glob('*/results/final/gds/*.gds'))
library = gdstk.read_gds(gdss[-1])
top_cells = library.top_level()

top_cells[0].write_svg('inverter.svg')
IPython.display.SVG('inverter.svg')

# %% [markdown]
# ## Metrics
#
# [Documentation](https://openlane.readthedocs.io/en/latest/reference/datapoint_definitions.html)

# %%
import pandas as pd
import pathlib

pd.options.display.max_rows = None
reports = sorted(pathlib.Path('runs').glob('*/reports/metrics.csv'))
df = pd.read_csv(reports[-1])
df.transpose()
# Out:
#                                                      0
# design                                        /content
# design_name                                   inverter
# config                         RUN_2023.05.26_14.31.45
# flow_status                             flow completed
# total_runtime                               0h0m47s0ms
# routed_runtime                              0h0m24s0ms
# (Cell/mm^2)/Core_Util                      4059.594852
# DIEAREA_mm^2                                  0.001971
# CellPer_mm^2                               2029.797426
# OpenDP_Util                                         -1
# Final_Util                                          -1
# Peak_Memory_Usage_MB                             467.5
# synth_cell_count                                     1
# tritonRoute_violations                               0
# Short_violations                                     0
# MetSpc_violations                                    0
# OffGrid_violations                                   0
# MinHole_violations                                   0
# Other_violations                                     0
# Magic_violations                                   271
# pin_antenna_violations                               0
# net_antenna_violations                               0
# lvs_total_errors                                     0
# cvc_total_errors                                    -1
# klayout_violations                                  -1
# wire_length                                        100
# vias                                                19
# wns                                                0.0
# pl_wns                                              -1
# optimized_wns                                       -1
# fastroute_wns                                       -1
# spef_wns                                           0.0
# tns                                                0.0
# pl_tns                                              -1
# optimized_tns                                       -1
# fastroute_tns                                       -1
# spef_tns                                           0.0
# HPWL                                                -1
# routing_layer1_pct                                 0.0
# routing_layer2_pct                                1.75
# routing_layer3_pct                                 2.1
# routing_layer4_pct                                 0.0
# routing_layer5_pct                                 0.0
# routing_layer6_pct                                 0.0
# wires_count                                          3
# wire_bits                                            3
# public_wires_count                                   3
# public_wire_bits                                     3
# memories_count                                       0
# memory_bits                                          0
# processes_count                                      0
# cells_pre_abc                                        1
# AND                                                  0
# DFF                                                  0
# NAND                                                 1
# NOR                                                  0
# OR                                                   0
# XOR                                                  0
# XNOR                                                 0
# MUX                                                  0
# inputs                                               2
# outputs                                              1
# level                                                1
# DecapCells                                          78
# WelltapCells                                         7
# DiodeCells                                           0
# FillCells                                           20
# NonPhysCells                                         4
# TotalCells                                         109
# CoreArea_um^2                                 829.5456
# power_slowest_internal_uW                           -1
# power_slowest_switching_uW                          -1
# power_slowest_leakage_uW                            -1
# power_typical_internal_uW                          0.0
# power_typical_switching_uW                    0.000001
# power_typical_leakage_uW                           0.0
# power_fastest_internal_uW                           -1
# power_fastest_switching_uW                          -1
# power_fastest_leakage_uW                            -1
# critical_path_ns                                  0.37
# suggested_clock_period                            10.0
# suggested_clock_frequency                        100.0
# CLOCK_PERIOD                                      10.0
# FP_ASPECT_RATIO                                      1
# FP_CORE_UTIL                                        50
# FP_PDN_HPITCH                                       25
# FP_PDN_VPITCH                                       25
# GRT_ADJUSTMENT                                     0.3
# GRT_REPAIR_ANTENNAS                                  1
# PL_TARGET_DENSITY                                 0.75
# RUN_HEURISTIC_DIODE_INSERTION                        0
# STD_CELL_LIBRARY                       sky130_fd_sc_hd
# SYNTH_MAX_FANOUT                                    10
# SYNTH_STRATEGY                                  AREA 0
